# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs
from mpl_toolkits.mplot3d import Axes3D

# %%
coordinates=[[2,2,3],[6,7,8],[5,10,13]]
x,y=make_blobs(n_samples=100,centers=coordinates,cluster_std=0.6)
print(x.shape)
print(y.shape)
# Out:
# (100, 3)
# (100,)

# %%
print(x[:4])
print(y)
# Out:
# [[1.69209176 1.3141874  3.36914103]
#  [2.19303429 2.69415444 2.17612967]
#  [2.01351189 1.87699035 2.59235418]
#  [2.17809388 2.3941329  1.97599777]]
# [0 0 0 0 0 2 0 2 1 1 0 2 2 1 2 2 2 2 1 0 0 1 1 2 1 1 0 1 2 0 0 1 0 0 1 2 1
#  2 1 1 0 1 0 1 2 0 2 0 2 2 1 0 0 1 1 2 0 2 0 0 0 1 1 1 0 2 1 1 1 0 0 2 0 0
#  0 1 2 1 0 2 2 1 1 0 1 0 2 2 2 2 2 1 1 0 2 1 2 2 2 2]

# %%
fig=plt.figure(figsize=(8,7))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(x[:,0],x[:,1],x[:,2],marker='o',color='blue')
plt.show()

# %%
msc=MeanShift(bandwidth=2)
msc.fit(x)
# Out:
# MeanShift(bandwidth=2)

# %%
print('Cluster Centers')
ccent=msc.cluster_centers_
print(ccent)
# Out:
# Cluster Centers
# [[ 2.01116033  2.18900301  2.98879963]
#  [ 5.96322237  7.0936642   7.93706945]
#  [ 4.86001762  9.88123627 12.90663104]]

# %%
ypred_msc=msc.predict(x)
print(ypred_msc)
# Out:
# [0 0 0 0 0 2 0 2 1 1 0 2 2 1 2 2 2 2 1 0 0 1 1 2 1 1 0 1 2 0 0 1 0 0 1 2 1
#  2 1 1 0 1 0 1 2 0 2 0 2 2 1 0 0 1 1 2 0 2 0 0 0 1 1 1 0 2 1 1 1 0 0 2 0 0
#  0 1 2 1 0 2 2 1 1 0 1 0 2 2 2 2 2 1 1 0 2 1 2 2 2 2]

# %%
cent5=k5.cluster_centers_
print(cent5)
# Out:
# [[26.30434783 20.91304348]
#  [86.53846154 82.12820513]
#  [55.2962963  49.51851852]
#  [88.2        17.11428571]
#  [25.72727273 79.36363636]]

# %%
fig=plt.figure(figsize=(8,7))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(x[:,0],x[:,1],x[:,2],marker='o',color='blue')
ax.scatter(ccent[:,0],ccent[:,1],ccent[:,2],marker='o',color='blue',s=200,linewidth=5)
plt.show()
